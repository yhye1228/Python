# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import KFold

# %%
my_images = []
labels = [0]*5 + [1]*5  # 내 얼굴 1, 타인 0

for i in range(10):
    file = f"./my_images/img{i+1:02d}.jpg"
    image = cv.imread(file)
    image = cv.resize(image, (96, 96))
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    my_images.append(image)

X = np.array(my_images, dtype='float32') / 255.0
y = np.array(labels)

# %%
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7,1.3],
    fill_mode='nearest'
)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold = 1
models = []

for train_index, val_index in kf.split(X):
    print(f"\n--- Fold {fold} ---")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    datagen.fit(X_train)

    # CNN 모델 정의
    model = keras.Sequential([
        keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(96,96,3)),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPooling2D((2,2)),

        keras.layers.Conv2D(64, (3,3), activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPooling2D((2,2)),

        keras.layers.Conv2D(64, (3,3), activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.Flatten(),

        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

    history = model.fit(
        datagen.flow(X_train, y_train, batch_size=2),
        validation_data=(X_val, y_val),
        epochs=200,
        callbacks=[early_stop],
        verbose=1
    )

    models.append(model)
    fold += 1
# Out:
# --- Fold 1 ---
# Epoch 1/200
# C:\Users\yhye1\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5000 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6868
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6868
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6250 - loss: 0.7508 - val_accuracy: 0.5000 - val_loss: 0.6909
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3750 - loss: 0.9992 - val_accuracy: 0.5000 - val_loss: 0.6995
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2500 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.7402
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6250 - loss: 0.8944 - val_accuracy: 0.5000 - val_loss: 0.8184
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6250 - loss: 0.6929 - val_accuracy: 0.5000 - val_loss: 0.8793
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6250 - loss: 0.6157 - val_accuracy: 0.5000 - val_loss: 0.9340
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5000 - loss: 1.6604 - val_accuracy: 0.5000 - val_loss: 0.9973
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5000 - loss: 1.1426 - val_accuracy: 0.5000 - val_loss: 1.0864
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5000 - loss: 2.9269 - val_accuracy: 0.5000 - val_loss: 1.2929
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6250 - loss: 0.5921 - val_accuracy: 0.5000 - val_loss: 1.5425
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5000 - loss: 1.1886 - val_accuracy: 0.5000 - val_loss: 1.7140
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5000 - loss: 1.5847 - val_accuracy: 0.5000 - val_loss: 1.7987
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5000 - loss: 1.5015 - val_accuracy: 0.5000 - val_loss: 1.9923
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2500 - loss: 2.3639 - val_accuracy: 0.5000 - val_loss: 2.1243
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6250 - loss: 3.3625 - val_accuracy: 0.5000 - val_loss: 2.3270
#
# --- Fold 2 ---
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.5000 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.7010
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5000 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.7015
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5000 - loss: 0.6136 - val_accuracy: 0.5000 - val_loss: 0.6998
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5000 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.7009
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5000 - loss: 1.0071 - val_accuracy: 0.5000 - val_loss: 0.7056
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5000 - loss: 1.2446 - val_accuracy: 0.5000 - val_loss: 0.7184
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5000 - loss: 1.8785 - val_accuracy: 0.5000 - val_loss: 0.7285
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6250 - loss: 1.3937 - val_accuracy: 0.5000 - val_loss: 0.7385
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6250 - loss: 0.5995 - val_accuracy: 0.5000 - val_loss: 0.7580
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3750 - loss: 0.6385 - val_accuracy: 0.5000 - val_loss: 0.7657
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5000 - loss: 1.0403 - val_accuracy: 0.5000 - val_loss: 0.7794
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5000 - loss: 0.6925 - val_accuracy: 0.5000 - val_loss: 0.7923
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6250 - loss: 0.9340 - val_accuracy: 0.5000 - val_loss: 0.8080
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7500 - loss: 0.5590 - val_accuracy: 0.5000 - val_loss: 0.8201
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6250 - loss: 1.7664 - val_accuracy: 0.5000 - val_loss: 0.8261
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5000 - loss: 0.6968 - val_accuracy: 0.5000 - val_loss: 0.8770
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5000 - loss: 0.9814 - val_accuracy: 0.5000 - val_loss: 0.9372
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3750 - loss: 3.8322 - val_accuracy: 0.5000 - val_loss: 1.0252
#
# --- Fold 3 ---
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.2500 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.7009
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 0.6153 - val_accuracy: 0.5000 - val_loss: 0.6952
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2500 - loss: 0.6716 - val_accuracy: 0.5000 - val_loss: 0.6938
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.3750 - loss: 1.6090 - val_accuracy: 0.5000 - val_loss: 0.7054
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5000 - loss: 0.6403 - val_accuracy: 0.5000 - val_loss: 0.7183
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.2500 - loss: 0.7511 - val_accuracy: 0.5000 - val_loss: 0.7331
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3750 - loss: 0.6936 - val_accuracy: 0.5000 - val_loss: 0.7490
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3750 - loss: 0.7054 - val_accuracy: 0.5000 - val_loss: 0.7497
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 0.3750 - loss: 0.9529 - val_accuracy: 0.5000 - val_loss: 0.7441
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.5000 - loss: 0.6861 - val_accuracy: 0.0000e+00 - val_loss: 0.7600
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.6250 - loss: 0.6928 - val_accuracy: 0.0000e+00 - val_loss: 0.7805
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.5000 - loss: 1.0861 - val_accuracy: 0.5000 - val_loss: 0.8112
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.7500 - loss: 0.6129 - val_accuracy: 0.5000 - val_loss: 0.8323
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.3750 - loss: 0.6387 - val_accuracy: 0.5000 - val_loss: 0.8578
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.6250 - loss: 1.7289 - val_accuracy: 0.5000 - val_loss: 0.9000
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.3750 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.9477
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.5000 - loss: 1.4777 - val_accuracy: 0.5000 - val_loss: 1.0349
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.2500 - loss: 0.8235 - val_accuracy: 0.5000 - val_loss: 1.0867
#
# --- Fold 4 ---
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 293ms/step - accuracy: 0.2500 - loss: 1.0706 - val_accuracy: 0.5000 - val_loss: 0.7044
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5000 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.7276
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3750 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.7526
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5000 - loss: 1.2271 - val_accuracy: 0.5000 - val_loss: 0.7921
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7500 - loss: 0.7631 - val_accuracy: 0.5000 - val_loss: 0.8944
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5000 - loss: 0.6843 - val_accuracy: 0.5000 - val_loss: 0.9753
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5000 - loss: 0.8797 - val_accuracy: 0.5000 - val_loss: 1.0270
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.3750 - loss: 0.6177 - val_accuracy: 0.5000 - val_loss: 1.1291
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5000 - loss: 0.9354 - val_accuracy: 0.5000 - val_loss: 1.1518
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5000 - loss: 0.6938 - val_accuracy: 0.5000 - val_loss: 1.3058
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.5000 - loss: 2.2297 - val_accuracy: 0.5000 - val_loss: 1.4491
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.3750 - loss: 1.4981 - val_accuracy: 0.5000 - val_loss: 1.6335
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.6250 - loss: 0.5321 - val_accuracy: 0.5000 - val_loss: 1.7849
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5000 - loss: 1.1944 - val_accuracy: 0.5000 - val_loss: 1.9827
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7500 - loss: 0.7204 - val_accuracy: 0.5000 - val_loss: 2.1317
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2500 - loss: 0.6980 - val_accuracy: 0.5000 - val_loss: 2.4582
#
# --- Fold 5 ---
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 298ms/step - accuracy: 0.5000 - loss: 0.6061 - val_accuracy: 0.5000 - val_loss: 0.7046
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.5000 - loss: 0.7510 - val_accuracy: 0.5000 - val_loss: 0.7020
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5000 - loss: 0.9021 - val_accuracy: 0.5000 - val_loss: 0.7004
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5000 - loss: 1.3792 - val_accuracy: 0.5000 - val_loss: 0.7080
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.5000 - loss: 0.5858 - val_accuracy: 0.5000 - val_loss: 0.7132
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.7500 - loss: 0.6371 - val_accuracy: 0.5000 - val_loss: 0.7204
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5000 - loss: 0.6458 - val_accuracy: 0.5000 - val_loss: 0.7224
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.5000 - loss: 0.6216 - val_accuracy: 0.5000 - val_loss: 0.7255
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5000 - loss: 0.8368 - val_accuracy: 0.5000 - val_loss: 0.7291
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.2500 - loss: 1.2722 - val_accuracy: 0.5000 - val_loss: 0.7475
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6250 - loss: 1.4032 - val_accuracy: 0.5000 - val_loss: 0.7847
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3750 - loss: 0.8022 - val_accuracy: 0.5000 - val_loss: 0.8549
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6250 - loss: 1.5586 - val_accuracy: 0.5000 - val_loss: 0.9162
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.1250 - loss: 0.8639 - val_accuracy: 0.5000 - val_loss: 1.0120
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5000 - loss: 1.3309 - val_accuracy: 0.5000 - val_loss: 1.0505
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.2500 - loss: 2.3215 - val_accuracy: 0.5000 - val_loss: 1.1205
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2500 - loss: 1.1015 - val_accuracy: 0.5000 - val_loss: 1.2876
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5000 - loss: 1.6984 - val_accuracy: 0.5000 - val_loss: 1.4200

# %%
test_images = []
for i in range(10):
    file = f"./test_images/img{i+1:02d}.jpg"
    image = cv.imread(file)
    image = cv.resize(image, (96, 96))
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    test_images.append(image)

test_images_arr = np.array(test_images, dtype='float32') / 255.0

# %%
predictions = np.zeros((len(test_images_arr), 1))
for model in models:
    predictions += model.predict(test_images_arr)

predictions /= len(models)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000157E882F380> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step

# %%
for i, p in enumerate(predictions):
    if p > 0.5:
        print(f"img{i+1:02d}.jpg → ✅ 내 얼굴 ({p[0]:.3f})")
    else:
        print(f"img{i+1:02d}.jpg → ❌ 타인 ({p[0]:.3f})")
# Out:
# img01.jpg → ❌ 타인 (0.488)
# img02.jpg → ❌ 타인 (0.485)
# img03.jpg → ❌ 타인 (0.481)
# img04.jpg → ❌ 타인 (0.488)
# img05.jpg → ❌ 타인 (0.485)
# img06.jpg → ❌ 타인 (0.482)
# img07.jpg → ❌ 타인 (0.482)
# img08.jpg → ❌ 타인 (0.483)
# img09.jpg → ❌ 타인 (0.487)
# img10.jpg → ❌ 타인 (0.482)
